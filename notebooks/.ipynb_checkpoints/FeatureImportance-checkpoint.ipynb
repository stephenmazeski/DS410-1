# %%
import corner
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import RFE, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.linear_model import (LinearRegression, Ridge, Lasso, RandomizedLasso)

# %%
df = pd.read_csv('../data/samples/smallSamples.csv', names = ["col1", "col2", "col3", "col4", "col5", "col6", "col7", "col8", "col9", "col10", "col11"])
# df = raw_data.to_pandas()
df.dropna()
df.head()
# Out:
#                                col1                              col2 col3  \
# 0  73495B48481E673AD8D7578764C9EC98  66DA261DA2E0305435786C152085CCC2  VTS
# 1  84888E642BC18ADDE60FD58AEB32988F  B75E4AA21928ED9F8D3A6D1D9BE6FDDD  VTS
# 2  B9139EC3A30D756DA319F00B3692A302  0D3990B4C4A72F7D66E1120FBA734DC2  CMT
# 3  546F967BDF8B5BF5866030CBEC05A5AD  DCD59CC7D99E043641476BA3DF8BB841  VTS
# 4  4D537A6203535DC996A76CB5BD41847C  600B03B6FC7DF50E52C39DDD511976A0  CMT
#
#                   col4 col5  col6  col7  col8  col9  col10  col11
# 0  2013-01-01 22:38:00  CSH  13.0   0.5   0.5   0.0    0.0   14.0
# 1  2013-01-05 01:02:00  CRD  16.5   0.5   0.5   3.0    0.0   20.5
# 2  2013-01-02 16:18:31  CSH   4.0   1.0   0.5   0.0    0.0    5.5
# 3  2013-01-17 16:45:00  CSH  10.0   1.0   0.5   0.0    0.0   11.5
# 4  2013-01-31 07:39:26  CSH   3.5   0.0   0.5   0.0    0.0    4.0

# %%
sns.pairplot(df)
plt.show()

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()
